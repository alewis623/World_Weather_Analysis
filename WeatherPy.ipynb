# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 594

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    print (city_url)
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.

        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except Exception as E: 
        #raise E
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=tumannyy
# Processing Record 1 of Set 1 | tumannyy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=lorengau
# Processing Record 2 of Set 1 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=hualmay
# Processing Record 3 of Set 1 | hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=torbay
# Processing Record 4 of Set 1 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=punta+arenas
# Processing Record 5 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=nampula
# Processing Record 6 of Set 1 | nampula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=bluff
# Processing Record 7 of Set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=flinders
# Processing Record 8 of Set 1 | flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=touros
# Processing Record 9 of Set 1 | touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=ryotsu
# Processing Record 10 of Set 1 | ryotsu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=stornoway
# Processing Record 11 of Set 1 | stornoway
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=khatanga
# Processing Record 12 of Set 1 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kodiak
# Processing Record 13 of Set 1 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=gamba
# Processing Record 14 of Set 1 | gamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=puerto+madryn
# Processing Record 15 of Set 1 | puerto madryn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=cao+bang
# Processing Record 16 of Set 1 | cao bang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kavieng
# Processing Record 17 of Set 1 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=aklavik
# Processing Record 18 of Set 1 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=mataura
# Processing Record 19 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=laguna
# Processing Record 20 of Set 1 | laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=maragogi
# Processing Record 21 of Set 1 | maragogi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=bethel
# Processing Record 22 of Set 1 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=yoichi
# Processing Record 23 of Set 1 | yoichi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=nizhneyansk
# Processing Record 24 of Set 1 | nizhneyansk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=mogadishu
# Processing Record 25 of Set 1 | mogadishu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=hilo
# Processing Record 26 of Set 1 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=ponta+do+sol
# Processing Record 27 of Set 1 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=barrow
# Processing Record 28 of Set 1 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=te+anau
# Processing Record 29 of Set 1 | te anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=marrakesh
# Processing Record 30 of Set 1 | marrakesh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=butaritari
# Processing Record 31 of Set 1 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=hithadhoo
# Processing Record 32 of Set 1 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=buchanan
# Processing Record 33 of Set 1 | buchanan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=puerto+ayora
# Processing Record 34 of Set 1 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=mrirt
# Processing Record 35 of Set 1 | mrirt
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=cidreira
# Processing Record 36 of Set 1 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=longyearbyen
# Processing Record 37 of Set 1 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=port+moresby
# Processing Record 38 of Set 1 | port moresby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=xining
# Processing Record 39 of Set 1 | xining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kasongo-lunda
# Processing Record 40 of Set 1 | kasongo-lunda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=sinnamary
# Processing Record 41 of Set 1 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=jalu
# Processing Record 42 of Set 1 | jalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=atuona
# Processing Record 43 of Set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kapaa
# Processing Record 44 of Set 1 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=albany
# Processing Record 45 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=barentsburg
# Processing Record 46 of Set 1 | barentsburg
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=santander
# Processing Record 47 of Set 1 | santander
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=mago
# Processing Record 48 of Set 1 | mago
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=qandala
# Processing Record 49 of Set 1 | qandala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=bambous+virieux
# Processing Record 50 of Set 1 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=avarua
# Processing Record 1 of Set 2 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=coruripe
# Processing Record 2 of Set 2 | coruripe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=taolanaro
# Processing Record 3 of Set 2 | taolanaro
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=ushuaia
# Processing Record 4 of Set 2 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=nkayi
# Processing Record 5 of Set 2 | nkayi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=saint+george
# Processing Record 6 of Set 2 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=hobart
# Processing Record 7 of Set 2 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=daniel+flores
# Processing Record 8 of Set 2 | daniel flores
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=hasaki
# Processing Record 9 of Set 2 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=sokoto
# Processing Record 10 of Set 2 | sokoto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=bredasdorp
# Processing Record 11 of Set 2 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kruisfontein
# Processing Record 12 of Set 2 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=mahebourg
# Processing Record 13 of Set 2 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=saskylakh
# Processing Record 14 of Set 2 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=nizwa
# Processing Record 15 of Set 2 | nizwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=sitka
# Processing Record 16 of Set 2 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=caravelas
# Processing Record 17 of Set 2 | caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=portland
# Processing Record 18 of Set 2 | portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=southampton
# Processing Record 19 of Set 2 | southampton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=mahibadhoo
# Processing Record 20 of Set 2 | mahibadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=hermanus
# Processing Record 21 of Set 2 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=vardo
# Processing Record 22 of Set 2 | vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=saint-philippe
# Processing Record 23 of Set 2 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=rikitea
# Processing Record 24 of Set 2 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=mar+del+plata
# Processing Record 25 of Set 2 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=ruatoria
# Processing Record 26 of Set 2 | ruatoria
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=gat
# Processing Record 27 of Set 2 | gat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=itacare
# Processing Record 28 of Set 2 | itacare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=zhireken
# Processing Record 29 of Set 2 | zhireken
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=onda
# Processing Record 30 of Set 2 | onda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=chuy
# Processing Record 31 of Set 2 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=gushikawa
# Processing Record 32 of Set 2 | gushikawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=iqaluit
# Processing Record 33 of Set 2 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=pisco
# Processing Record 34 of Set 2 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=georgetown
# Processing Record 35 of Set 2 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=muheza
# Processing Record 36 of Set 2 | muheza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=poum
# Processing Record 37 of Set 2 | poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=cape+town
# Processing Record 38 of Set 2 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=padang
# Processing Record 39 of Set 2 | padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=comodoro+rivadavia
# Processing Record 40 of Set 2 | comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=waingapu
# Processing Record 41 of Set 2 | waingapu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=narsaq
# Processing Record 42 of Set 2 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=channel-port+aux+basques
# Processing Record 43 of Set 2 | channel-port aux basques
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=tornio
# Processing Record 44 of Set 2 | tornio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=calama
# Processing Record 45 of Set 2 | calama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=pizarro
# Processing Record 46 of Set 2 | pizarro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=san+pedro+de+macoris
# Processing Record 47 of Set 2 | san pedro de macoris
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=talaya
# Processing Record 48 of Set 2 | talaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=tuktoyaktuk
# Processing Record 49 of Set 2 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=klaksvik
# Processing Record 50 of Set 2 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=busselton
# Processing Record 1 of Set 3 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=gloversville
# Processing Record 2 of Set 3 | gloversville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=vaitupu
# Processing Record 3 of Set 3 | vaitupu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=qaanaaq
# Processing Record 4 of Set 3 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=tambacounda
# Processing Record 5 of Set 3 | tambacounda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=constitucion
# Processing Record 6 of Set 3 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=namwala
# Processing Record 7 of Set 3 | namwala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=puerto+del+rosario
# Processing Record 8 of Set 3 | puerto del rosario
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=porto+belo
# Processing Record 9 of Set 3 | porto belo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=karauzyak
# Processing Record 10 of Set 3 | karauzyak
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=warqla
# Processing Record 11 of Set 3 | warqla
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=faanui
# Processing Record 12 of Set 3 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=vostok
# Processing Record 13 of Set 3 | vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=sorong
# Processing Record 14 of Set 3 | sorong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=arraial+do+cabo
# Processing Record 15 of Set 3 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=dikson
# Processing Record 16 of Set 3 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=rotenburg
# Processing Record 17 of Set 3 | rotenburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=sebinkarahisar
# Processing Record 18 of Set 3 | sebinkarahisar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=port+lincoln
# Processing Record 19 of Set 3 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=jamestown
# Processing Record 20 of Set 3 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=timmins
# Processing Record 21 of Set 3 | timmins
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=mehamn
# Processing Record 22 of Set 3 | mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=mehran
# Processing Record 23 of Set 3 | mehran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=srandakan
# Processing Record 24 of Set 3 | srandakan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=monte+patria
# Processing Record 25 of Set 3 | monte patria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=norman+wells
# Processing Record 26 of Set 3 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=new+norfolk
# Processing Record 27 of Set 3 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=beringovskiy
# Processing Record 28 of Set 3 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=victoria
# Processing Record 29 of Set 3 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=paamiut
# Processing Record 30 of Set 3 | paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=nikolskoye
# Processing Record 31 of Set 3 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=jinchang
# Processing Record 32 of Set 3 | jinchang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=grand+river+south+east
# Processing Record 33 of Set 3 | grand river south east
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=srednekolymsk
# Processing Record 34 of Set 3 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=tabukiniberu
# Processing Record 35 of Set 3 | tabukiniberu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=aksu
# Processing Record 36 of Set 3 | aksu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=banmo
# Processing Record 37 of Set 3 | banmo
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=amderma
# Processing Record 38 of Set 3 | amderma
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kuytun
# Processing Record 39 of Set 3 | kuytun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=cockburn+town
# Processing Record 40 of Set 3 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=portobelo
# Processing Record 41 of Set 3 | portobelo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=yaan
# Processing Record 42 of Set 3 | yaan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=nurota
# Processing Record 43 of Set 3 | nurota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=alofi
# Processing Record 44 of Set 3 | alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=harnosand
# Processing Record 45 of Set 3 | harnosand
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=katsuura
# Processing Record 46 of Set 3 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=guelengdeng
# Processing Record 47 of Set 3 | guelengdeng
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=samarai
# Processing Record 48 of Set 3 | samarai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=havre-saint-pierre
# Processing Record 49 of Set 3 | havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=illoqqortoormiut
# Processing Record 50 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=urusha
# Processing Record 1 of Set 4 | urusha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=souillac
# Processing Record 2 of Set 4 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=teodoro+sampaio
# Processing Record 3 of Set 4 | teodoro sampaio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=palmer
# Processing Record 4 of Set 4 | palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=san+pedro
# Processing Record 5 of Set 4 | san pedro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=komsomolskiy
# Processing Record 6 of Set 4 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kaitangata
# Processing Record 7 of Set 4 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=ilulissat
# Processing Record 8 of Set 4 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=pitea
# Processing Record 9 of Set 4 | pitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=road+town
# Processing Record 10 of Set 4 | road town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=castro
# Processing Record 11 of Set 4 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=uray
# Processing Record 12 of Set 4 | uray
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=rawson
# Processing Record 13 of Set 4 | rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=raudeberg
# Processing Record 14 of Set 4 | raudeberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=sechura
# Processing Record 15 of Set 4 | sechura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=borogontsy
# Processing Record 16 of Set 4 | borogontsy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=cayenne
# Processing Record 17 of Set 4 | cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=sayansk
# Processing Record 18 of Set 4 | sayansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=richards+bay
# Processing Record 19 of Set 4 | richards bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=fortuna
# Processing Record 20 of Set 4 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=orocue
# Processing Record 21 of Set 4 | orocue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=tsihombe
# Processing Record 22 of Set 4 | tsihombe
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=merauke
# Processing Record 23 of Set 4 | merauke
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=san+juan
# Processing Record 24 of Set 4 | san juan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=boyolangu
# Processing Record 25 of Set 4 | boyolangu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=bergen
# Processing Record 26 of Set 4 | bergen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=carinhanha
# Processing Record 27 of Set 4 | carinhanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=port+elizabeth
# Processing Record 28 of Set 4 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=vigrestad
# Processing Record 29 of Set 4 | vigrestad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=xichang
# Processing Record 30 of Set 4 | xichang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=buraydah
# Processing Record 31 of Set 4 | buraydah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=ancud
# Processing Record 32 of Set 4 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=belogorsk
# Processing Record 33 of Set 4 | belogorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=antalaha
# Processing Record 34 of Set 4 | antalaha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kamenskoye
# Processing Record 35 of Set 4 | kamenskoye
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=nguiu
# Processing Record 36 of Set 4 | nguiu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=margate
# Processing Record 37 of Set 4 | margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=yellowknife
# Processing Record 38 of Set 4 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=dehui
# Processing Record 39 of Set 4 | dehui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=quatre+cocos
# Processing Record 40 of Set 4 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=tefe
# Processing Record 41 of Set 4 | tefe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=amarante+do+maranhao
# Processing Record 42 of Set 4 | amarante do maranhao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=belushya+guba
# Processing Record 43 of Set 4 | belushya guba
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=oktyabrskiy
# Processing Record 44 of Set 4 | oktyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=cutlerville
# Processing Record 45 of Set 4 | cutlerville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=tezu
# Processing Record 46 of Set 4 | tezu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=walvis+bay
# Processing Record 47 of Set 4 | walvis bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=nelson+bay
# Processing Record 48 of Set 4 | nelson bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=ati
# Processing Record 49 of Set 4 | ati
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=fort+nelson
# Processing Record 50 of Set 4 | fort nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=nara
# Processing Record 1 of Set 5 | nara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=leh
# Processing Record 2 of Set 5 | leh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=poya
# Processing Record 3 of Set 5 | poya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=bekovo
# Processing Record 4 of Set 5 | bekovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=zermatt
# Processing Record 5 of Set 5 | zermatt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=cheney
# Processing Record 6 of Set 5 | cheney
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=chokurdakh
# Processing Record 7 of Set 5 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=salalah
# Processing Record 8 of Set 5 | salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=pangnirtung
# Processing Record 9 of Set 5 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=taburao
# Processing Record 10 of Set 5 | taburao
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=paoua
# Processing Record 11 of Set 5 | paoua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=luderitz
# Processing Record 12 of Set 5 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=thompson
# Processing Record 13 of Set 5 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kieta
# Processing Record 14 of Set 5 | kieta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=vilcun
# Processing Record 15 of Set 5 | vilcun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=sao+filipe
# Processing Record 16 of Set 5 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=mount+isa
# Processing Record 17 of Set 5 | mount isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=alice+springs
# Processing Record 18 of Set 5 | alice springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=hervey+bay
# Processing Record 19 of Set 5 | hervey bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=tucuma
# Processing Record 20 of Set 5 | tucuma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=sinop
# Processing Record 21 of Set 5 | sinop
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=brodick
# Processing Record 22 of Set 5 | brodick
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=chemal
# Processing Record 23 of Set 5 | chemal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=murbad
# Processing Record 24 of Set 5 | murbad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=nome
# Processing Record 25 of Set 5 | nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=huarmey
# Processing Record 26 of Set 5 | huarmey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=cherskiy
# Processing Record 27 of Set 5 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=taoudenni
# Processing Record 28 of Set 5 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kotido
# Processing Record 29 of Set 5 | kotido
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=port+alfred
# Processing Record 30 of Set 5 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kollam
# Processing Record 31 of Set 5 | kollam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=esperance
# Processing Record 32 of Set 5 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=tiksi
# Processing Record 33 of Set 5 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=denpasar
# Processing Record 34 of Set 5 | denpasar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=naze
# Processing Record 35 of Set 5 | naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=carnarvon
# Processing Record 36 of Set 5 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=airai
# Processing Record 37 of Set 5 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=riyadh
# Processing Record 38 of Set 5 | riyadh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=san+patricio
# Processing Record 39 of Set 5 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=upernavik
# Processing Record 40 of Set 5 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=auki
# Processing Record 41 of Set 5 | auki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=rawah
# Processing Record 42 of Set 5 | rawah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=honningsvag
# Processing Record 43 of Set 5 | honningsvag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=samana
# Processing Record 44 of Set 5 | samana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=umm+lajj
# Processing Record 45 of Set 5 | umm lajj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=nanortalik
# Processing Record 46 of Set 5 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=manuk+mangkaw
# Processing Record 47 of Set 5 | manuk mangkaw
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=bathsheba
# Processing Record 48 of Set 5 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=smithers
# Processing Record 49 of Set 5 | smithers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=palabuhanratu
# Processing Record 50 of Set 5 | palabuhanratu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=regina
# Processing Record 1 of Set 6 | regina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=sur
# Processing Record 2 of Set 6 | sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=ahipara
# Processing Record 3 of Set 6 | ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=najran
# Processing Record 4 of Set 6 | najran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=leningradskiy
# Processing Record 5 of Set 6 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=quelimane
# Processing Record 6 of Set 6 | quelimane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=codrington
# Processing Record 7 of Set 6 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=camana
# Processing Record 8 of Set 6 | camana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=elk+plain
# Processing Record 9 of Set 6 | elk plain
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=east+london
# Processing Record 10 of Set 6 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=bolshaya+sosnova
# Processing Record 11 of Set 6 | bolshaya sosnova
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=mayo
# Processing Record 12 of Set 6 | mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=yanchukan
# Processing Record 13 of Set 6 | yanchukan
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=mandla
# Processing Record 14 of Set 6 | mandla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=bodden+town
# Processing Record 15 of Set 6 | bodden town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=safford
# Processing Record 16 of Set 6 | safford
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=doka
# Processing Record 17 of Set 6 | doka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=arrecife
# Processing Record 18 of Set 6 | arrecife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=ramanuj+ganj
# Processing Record 19 of Set 6 | ramanuj ganj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=maloy
# Processing Record 20 of Set 6 | maloy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=busilac
# Processing Record 21 of Set 6 | busilac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=nikologory
# Processing Record 22 of Set 6 | nikologory
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=rundu
# Processing Record 23 of Set 6 | rundu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=san+cristobal
# Processing Record 24 of Set 6 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=cairns
# Processing Record 25 of Set 6 | cairns
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=cap+malheureux
# Processing Record 26 of Set 6 | cap malheureux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=ardmore
# Processing Record 27 of Set 6 | ardmore
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=mocambique
# Processing Record 28 of Set 6 | mocambique
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=hofn
# Processing Record 29 of Set 6 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=pudozh
# Processing Record 30 of Set 6 | pudozh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=vaini
# Processing Record 31 of Set 6 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=portel
# Processing Record 32 of Set 6 | portel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=tubuala
# Processing Record 33 of Set 6 | tubuala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=haines+junction
# Processing Record 34 of Set 6 | haines junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=cabo+san+lucas
# Processing Record 35 of Set 6 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=ortigueira
# Processing Record 36 of Set 6 | ortigueira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=trofors
# Processing Record 37 of Set 6 | trofors
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=namatanai
# Processing Record 38 of Set 6 | namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=rapid+valley
# Processing Record 39 of Set 6 | rapid valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=san+quintin
# Processing Record 40 of Set 6 | san quintin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=cozumel
# Processing Record 41 of Set 6 | cozumel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=coquimbo
# Processing Record 42 of Set 6 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=saleaula
# Processing Record 43 of Set 6 | saleaula
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=ixtapa
# Processing Record 44 of Set 6 | ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=itoman
# Processing Record 45 of Set 6 | itoman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=havelock
# Processing Record 46 of Set 6 | havelock
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=denham+springs
# Processing Record 47 of Set 6 | denham springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kogon
# Processing Record 48 of Set 6 | kogon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=manokwari
# Processing Record 49 of Set 6 | manokwari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=cabedelo
# Processing Record 50 of Set 6 | cabedelo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=muvattupula
# Processing Record 1 of Set 7 | muvattupula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=mareeba
# Processing Record 2 of Set 7 | mareeba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=ramacca
# Processing Record 3 of Set 7 | ramacca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=bukama
# Processing Record 4 of Set 7 | bukama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=zemio
# Processing Record 5 of Set 7 | zemio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kimbe
# Processing Record 6 of Set 7 | kimbe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=grand+gaube
# Processing Record 7 of Set 7 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=nouadhibou
# Processing Record 8 of Set 7 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kloulklubed
# Processing Record 9 of Set 7 | kloulklubed
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=chongwe
# Processing Record 10 of Set 7 | chongwe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=lompoc
# Processing Record 11 of Set 7 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=skjervoy
# Processing Record 12 of Set 7 | skjervoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=bajil
# Processing Record 13 of Set 7 | bajil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=urumqi
# Processing Record 14 of Set 7 | urumqi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=aripuana
# Processing Record 15 of Set 7 | aripuana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=mugur-aksy
# Processing Record 16 of Set 7 | mugur-aksy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=atar
# Processing Record 17 of Set 7 | atar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=sisimiut
# Processing Record 18 of Set 7 | sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=obera
# Processing Record 19 of Set 7 | obera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=ribeira+grande
# Processing Record 20 of Set 7 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=hammerfest
# Processing Record 21 of Set 7 | hammerfest
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=umzimvubu
# Processing Record 22 of Set 7 | umzimvubu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=wake+forest
# Processing Record 23 of Set 7 | wake forest
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=avera
# Processing Record 24 of Set 7 | avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=lichinga
# Processing Record 25 of Set 7 | lichinga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=samusu
# Processing Record 26 of Set 7 | samusu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=provideniya
# Processing Record 27 of Set 7 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=grindavik
# Processing Record 28 of Set 7 | grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kalianget
# Processing Record 29 of Set 7 | kalianget
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=bure
# Processing Record 30 of Set 7 | bure
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=port+blair
# Processing Record 31 of Set 7 | port blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=santa+maria
# Processing Record 32 of Set 7 | santa maria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=khandbari
# Processing Record 33 of Set 7 | khandbari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=santa+cruz
# Processing Record 34 of Set 7 | santa cruz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=yar-sale
# Processing Record 35 of Set 7 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=vao
# Processing Record 36 of Set 7 | vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=fairbanks
# Processing Record 37 of Set 7 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=hovd
# Processing Record 38 of Set 7 | hovd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=severo-kurilsk
# Processing Record 39 of Set 7 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=wilmington
# Processing Record 40 of Set 7 | wilmington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=sentyabrskiy
# Processing Record 41 of Set 7 | sentyabrskiy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=teknaf
# Processing Record 42 of Set 7 | teknaf
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=axim
# Processing Record 43 of Set 7 | axim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=abeokuta
# Processing Record 44 of Set 7 | abeokuta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=manggar
# Processing Record 45 of Set 7 | manggar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=giyani
# Processing Record 46 of Set 7 | giyani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=velasco+ibarra
# Processing Record 47 of Set 7 | velasco ibarra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=xingyi
# Processing Record 48 of Set 7 | xingyi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=mezen
# Processing Record 49 of Set 7 | mezen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=ambodifototra
# Processing Record 50 of Set 7 | ambodifototra
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=hit
# Processing Record 1 of Set 8 | hit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=alta+floresta
# Processing Record 2 of Set 8 | alta floresta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=skibbereen
# Processing Record 3 of Set 8 | skibbereen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kurchum
# Processing Record 4 of Set 8 | kurchum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=alugan
# Processing Record 5 of Set 8 | alugan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kurumkan
# Processing Record 6 of Set 8 | kurumkan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=vestmannaeyjar
# Processing Record 7 of Set 8 | vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=mangrol
# Processing Record 8 of Set 8 | mangrol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kovur
# Processing Record 9 of Set 8 | kovur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=saldanha
# Processing Record 10 of Set 8 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=lata
# Processing Record 11 of Set 8 | lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=biak
# Processing Record 12 of Set 8 | biak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kununurra
# Processing Record 13 of Set 8 | kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=calatrava
# Processing Record 14 of Set 8 | calatrava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=tazovskiy
# Processing Record 15 of Set 8 | tazovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=tateyama
# Processing Record 16 of Set 8 | tateyama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=colac
# Processing Record 17 of Set 8 | colac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=royan
# Processing Record 18 of Set 8 | royan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=miandrivazo
# Processing Record 19 of Set 8 | miandrivazo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=port+hueneme
# Processing Record 20 of Set 8 | port hueneme
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=muncie
# Processing Record 21 of Set 8 | muncie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=nyeri
# Processing Record 22 of Set 8 | nyeri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=bargal
# Processing Record 23 of Set 8 | bargal
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=maralal
# Processing Record 24 of Set 8 | maralal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=shorapani
# Processing Record 25 of Set 8 | shorapani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kushiro
# Processing Record 26 of Set 8 | kushiro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kyaikto
# Processing Record 27 of Set 8 | kyaikto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kavaratti
# Processing Record 28 of Set 8 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=tessalit
# Processing Record 29 of Set 8 | tessalit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=necochea
# Processing Record 30 of Set 8 | necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=khonuu
# Processing Record 31 of Set 8 | khonuu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=makakilo+city
# Processing Record 32 of Set 8 | makakilo city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=alihe
# Processing Record 33 of Set 8 | alihe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=great+yarmouth
# Processing Record 34 of Set 8 | great yarmouth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=znamenskoye
# Processing Record 35 of Set 8 | znamenskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=malartic
# Processing Record 36 of Set 8 | malartic
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=ridgecrest
# Processing Record 37 of Set 8 | ridgecrest
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=huejuquilla+el+alto
# Processing Record 38 of Set 8 | huejuquilla el alto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=simao
# Processing Record 39 of Set 8 | simao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=herat
# Processing Record 40 of Set 8 | herat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=tasiilaq
# Processing Record 41 of Set 8 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=vila+velha
# Processing Record 42 of Set 8 | vila velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=villa+florida
# Processing Record 43 of Set 8 | villa florida
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=miyako
# Processing Record 44 of Set 8 | miyako
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=bitung
# Processing Record 45 of Set 8 | bitung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=burnie
# Processing Record 46 of Set 8 | burnie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=katobu
# Processing Record 47 of Set 8 | katobu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=capaccio
# Processing Record 48 of Set 8 | capaccio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=banyo
# Processing Record 49 of Set 8 | banyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=scarborough
# Processing Record 50 of Set 8 | scarborough

# %%
len(city_data)

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Get today's date in seconds.
today = time.strftime("%x")
today

# %%
# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-50,90))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(-50,15))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Wind Speed', 'Wind Speed',(-50,35))
