# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the API key.
from config import weather_api_key
# Out:
#   File "<ipython-input-7-2664ffbc66e3>", line 2
#     .from(config, import, weather_api_key)
#     ^
# SyntaxError: invalid syntax

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 761

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    print (city_url)
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.

        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_current})

# If an error is experienced, skip the city.
    except Exception as E: 
        #raise E
        print("City not found. Skipping...")
        #pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=dikson
# Processing Record 1 of Set 1 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=khormuj
# Processing Record 2 of Set 1 | khormuj
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=vaini
# Processing Record 3 of Set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=ponta+do+sol
# Processing Record 4 of Set 1 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=butaritari
# Processing Record 5 of Set 1 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=nizwa
# Processing Record 6 of Set 1 | nizwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kahului
# Processing Record 7 of Set 1 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=aflu
# Processing Record 8 of Set 1 | aflu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=aanekoski
# Processing Record 9 of Set 1 | aanekoski
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=rikitea
# Processing Record 10 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=constitucion
# Processing Record 11 of Set 1 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=shache
# Processing Record 12 of Set 1 | shache
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=bredasdorp
# Processing Record 13 of Set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=ahipara
# Processing Record 14 of Set 1 | ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=barrow
# Processing Record 15 of Set 1 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=avarua
# Processing Record 16 of Set 1 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=nikolskoye
# Processing Record 17 of Set 1 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=tasiilaq
# Processing Record 18 of Set 1 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=mataura
# Processing Record 19 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=turukhansk
# Processing Record 20 of Set 1 | turukhansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=fortuna
# Processing Record 21 of Set 1 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=melville
# Processing Record 22 of Set 1 | melville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=antofagasta
# Processing Record 23 of Set 1 | antofagasta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=ushuaia
# Processing Record 24 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kavieng
# Processing Record 25 of Set 1 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=jamestown
# Processing Record 26 of Set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=port+alfred
# Processing Record 27 of Set 1 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=mrakovo
# Processing Record 28 of Set 1 | mrakovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=najran
# Processing Record 29 of Set 1 | najran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=atar
# Processing Record 30 of Set 1 | atar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=hamilton
# Processing Record 31 of Set 1 | hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=grand+river+south+east
# Processing Record 32 of Set 1 | grand river south east
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=bocaranga
# Processing Record 33 of Set 1 | bocaranga
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=severnyy
# Processing Record 34 of Set 1 | severnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=hasaki
# Processing Record 35 of Set 1 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=saldanha
# Processing Record 36 of Set 1 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=oranjemund
# Processing Record 37 of Set 1 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=sumbawa
# Processing Record 38 of Set 1 | sumbawa
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=barra+do+garcas
# Processing Record 39 of Set 1 | barra do garcas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=busselton
# Processing Record 40 of Set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=moerai
# Processing Record 41 of Set 1 | moerai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=airai
# Processing Record 42 of Set 1 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=marsh+harbour
# Processing Record 43 of Set 1 | marsh harbour
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=yellowknife
# Processing Record 44 of Set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=geraldton
# Processing Record 45 of Set 1 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=belushya+guba
# Processing Record 46 of Set 1 | belushya guba
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=tiznit
# Processing Record 47 of Set 1 | tiznit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=zhigansk
# Processing Record 48 of Set 1 | zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=mandera
# Processing Record 49 of Set 1 | mandera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=louisbourg
# Processing Record 50 of Set 1 | louisbourg
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=honolulu
# Processing Record 1 of Set 2 | honolulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=punta+arenas
# Processing Record 2 of Set 2 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=ilulissat
# Processing Record 3 of Set 2 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=caucaia
# Processing Record 4 of Set 2 | caucaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=chuy
# Processing Record 5 of Set 2 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=terenos
# Processing Record 6 of Set 2 | terenos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=sobolevo
# Processing Record 7 of Set 2 | sobolevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=thompson
# Processing Record 8 of Set 2 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=castro
# Processing Record 9 of Set 2 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=yar-sale
# Processing Record 10 of Set 2 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=barbar
# Processing Record 11 of Set 2 | barbar
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=new+norfolk
# Processing Record 12 of Set 2 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=agirish
# Processing Record 13 of Set 2 | agirish
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kutina
# Processing Record 14 of Set 2 | kutina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=esperance
# Processing Record 15 of Set 2 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=illoqqortoormiut
# Processing Record 16 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=mount+gambier
# Processing Record 17 of Set 2 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=amapa
# Processing Record 18 of Set 2 | amapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=albany
# Processing Record 19 of Set 2 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=saint-augustin
# Processing Record 20 of Set 2 | saint-augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kaspiyskiy
# Processing Record 21 of Set 2 | kaspiyskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=longyearbyen
# Processing Record 22 of Set 2 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kaseda
# Processing Record 23 of Set 2 | kaseda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=cherskiy
# Processing Record 24 of Set 2 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=sribne
# Processing Record 25 of Set 2 | sribne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=port-gentil
# Processing Record 26 of Set 2 | port-gentil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=urengoy
# Processing Record 27 of Set 2 | urengoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kodiak
# Processing Record 28 of Set 2 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=khatanga
# Processing Record 29 of Set 2 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=tuktoyaktuk
# Processing Record 30 of Set 2 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=atuona
# Processing Record 31 of Set 2 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=port+elizabeth
# Processing Record 32 of Set 2 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=saint+george
# Processing Record 33 of Set 2 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=tallahassee
# Processing Record 34 of Set 2 | tallahassee
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=tilichiki
# Processing Record 35 of Set 2 | tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=meyungs
# Processing Record 36 of Set 2 | meyungs
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=yuxia
# Processing Record 37 of Set 2 | yuxia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=obihiro
# Processing Record 38 of Set 2 | obihiro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=hobart
# Processing Record 39 of Set 2 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=vaitupu
# Processing Record 40 of Set 2 | vaitupu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=tomatlan
# Processing Record 41 of Set 2 | tomatlan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=hermanus
# Processing Record 42 of Set 2 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=mys+shmidta
# Processing Record 43 of Set 2 | mys shmidta
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=georgetown
# Processing Record 44 of Set 2 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=mandalgovi
# Processing Record 45 of Set 2 | mandalgovi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=aklavik
# Processing Record 46 of Set 2 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=luderitz
# Processing Record 47 of Set 2 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=taolanaro
# Processing Record 48 of Set 2 | taolanaro
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=ribeira+grande
# Processing Record 49 of Set 2 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=puerto+ayora
# Processing Record 50 of Set 2 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=novobirilyussy
# Processing Record 1 of Set 3 | novobirilyussy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=deputatskiy
# Processing Record 2 of Set 3 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=qaanaaq
# Processing Record 3 of Set 3 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=chifeng
# Processing Record 4 of Set 3 | chifeng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=lazaro+cardenas
# Processing Record 5 of Set 3 | lazaro cardenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=college
# Processing Record 6 of Set 3 | college
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=aksha
# Processing Record 7 of Set 3 | aksha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=bethel
# Processing Record 8 of Set 3 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kapaa
# Processing Record 9 of Set 3 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=bluff
# Processing Record 10 of Set 3 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=tabiauea
# Processing Record 11 of Set 3 | tabiauea
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=victoria
# Processing Record 12 of Set 3 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=yuksekova
# Processing Record 13 of Set 3 | yuksekova
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=pevek
# Processing Record 14 of Set 3 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=tuatapere
# Processing Record 15 of Set 3 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=lowestoft
# Processing Record 16 of Set 3 | lowestoft
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=port+blair
# Processing Record 17 of Set 3 | port blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=henties+bay
# Processing Record 18 of Set 3 | henties bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=severo-kurilsk
# Processing Record 19 of Set 3 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=cape+town
# Processing Record 20 of Set 3 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=safranbolu
# Processing Record 21 of Set 3 | safranbolu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=yangshan
# Processing Record 22 of Set 3 | yangshan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=flin+flon
# Processing Record 23 of Set 3 | flin flon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=klaksvik
# Processing Record 24 of Set 3 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=arraial+do+cabo
# Processing Record 25 of Set 3 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kruisfontein
# Processing Record 26 of Set 3 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=narsaq
# Processing Record 27 of Set 3 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=bengkulu
# Processing Record 28 of Set 3 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=neiafu
# Processing Record 29 of Set 3 | neiafu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=riaba
# Processing Record 30 of Set 3 | riaba
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=lata
# Processing Record 31 of Set 3 | lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kologriv
# Processing Record 32 of Set 3 | kologriv
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=mar+del+plata
# Processing Record 33 of Set 3 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=tiksi
# Processing Record 34 of Set 3 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kaitangata
# Processing Record 35 of Set 3 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=mahebourg
# Processing Record 36 of Set 3 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=barentsburg
# Processing Record 37 of Set 3 | barentsburg
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=upernavik
# Processing Record 38 of Set 3 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=chokurdakh
# Processing Record 39 of Set 3 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=komsomolskiy
# Processing Record 40 of Set 3 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=beringovskiy
# Processing Record 41 of Set 3 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=hilo
# Processing Record 42 of Set 3 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=san+patricio
# Processing Record 43 of Set 3 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=bull+savanna
# Processing Record 44 of Set 3 | bull savanna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=mugreyevskiy
# Processing Record 45 of Set 3 | mugreyevskiy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=touros
# Processing Record 46 of Set 3 | touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=vestmannaeyjar
# Processing Record 47 of Set 3 | vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=nanortalik
# Processing Record 48 of Set 3 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=arkhangelos
# Processing Record 49 of Set 3 | arkhangelos
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=sergeyevka
# Processing Record 50 of Set 3 | sergeyevka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=hithadhoo
# Processing Record 1 of Set 4 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=tura
# Processing Record 2 of Set 4 | tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=wanning
# Processing Record 3 of Set 4 | wanning
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=vao
# Processing Record 4 of Set 4 | vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=bousse
# Processing Record 5 of Set 4 | bousse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=clyde+river
# Processing Record 6 of Set 4 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=lagoa
# Processing Record 7 of Set 4 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=saint+pete+beach
# Processing Record 8 of Set 4 | saint pete beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=entre+rios
# Processing Record 9 of Set 4 | entre rios
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=acapulco
# Processing Record 10 of Set 4 | acapulco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kazalinsk
# Processing Record 11 of Set 4 | kazalinsk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=requena
# Processing Record 12 of Set 4 | requena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=tonj
# Processing Record 13 of Set 4 | tonj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=iqaluit
# Processing Record 14 of Set 4 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=husavik
# Processing Record 15 of Set 4 | husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=port+lincoln
# Processing Record 16 of Set 4 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=la+ronge
# Processing Record 17 of Set 4 | la ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=hammerfest
# Processing Record 18 of Set 4 | hammerfest
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=chicama
# Processing Record 19 of Set 4 | chicama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=salalah
# Processing Record 20 of Set 4 | salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=fuerte+olimpo
# Processing Record 21 of Set 4 | fuerte olimpo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=sitka
# Processing Record 22 of Set 4 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=rapid+valley
# Processing Record 23 of Set 4 | rapid valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kemijarvi
# Processing Record 24 of Set 4 | kemijarvi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=cairo
# Processing Record 25 of Set 4 | cairo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=sao+filipe
# Processing Record 26 of Set 4 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=sinnamary
# Processing Record 27 of Set 4 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=port-cartier
# Processing Record 28 of Set 4 | port-cartier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=tessalit
# Processing Record 29 of Set 4 | tessalit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=haibowan
# Processing Record 30 of Set 4 | haibowan
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=ostrovnoy
# Processing Record 31 of Set 4 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=nagykata
# Processing Record 32 of Set 4 | nagykata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=flers
# Processing Record 33 of Set 4 | flers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=neuquen
# Processing Record 34 of Set 4 | neuquen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=slatina
# Processing Record 35 of Set 4 | slatina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=mlonggo
# Processing Record 36 of Set 4 | mlonggo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=coolum+beach
# Processing Record 37 of Set 4 | coolum beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=samusu
# Processing Record 38 of Set 4 | samusu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=matay
# Processing Record 39 of Set 4 | matay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=east+london
# Processing Record 40 of Set 4 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=winslow
# Processing Record 41 of Set 4 | winslow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=solsvik
# Processing Record 42 of Set 4 | solsvik
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=gushikawa
# Processing Record 43 of Set 4 | gushikawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=tigil
# Processing Record 44 of Set 4 | tigil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=pisco
# Processing Record 45 of Set 4 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=maneadero
# Processing Record 46 of Set 4 | maneadero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=jumla
# Processing Record 47 of Set 4 | jumla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=gamba
# Processing Record 48 of Set 4 | gamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=fairlie
# Processing Record 49 of Set 4 | fairlie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=bambous+virieux
# Processing Record 50 of Set 4 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=lyaskelya
# Processing Record 1 of Set 5 | lyaskelya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=danilovka
# Processing Record 2 of Set 5 | danilovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=barras
# Processing Record 3 of Set 5 | barras
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=wapakoneta
# Processing Record 4 of Set 5 | wapakoneta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=tsotilion
# Processing Record 5 of Set 5 | tsotilion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kirakira
# Processing Record 6 of Set 5 | kirakira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=bathsheba
# Processing Record 7 of Set 5 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=tezu
# Processing Record 8 of Set 5 | tezu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=maputo
# Processing Record 9 of Set 5 | maputo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=lorengau
# Processing Record 10 of Set 5 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=yeppoon
# Processing Record 11 of Set 5 | yeppoon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=djibo
# Processing Record 12 of Set 5 | djibo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=torquay
# Processing Record 13 of Set 5 | torquay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=ulaangom
# Processing Record 14 of Set 5 | ulaangom
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=shakawe
# Processing Record 15 of Set 5 | shakawe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=camp+verde
# Processing Record 16 of Set 5 | camp verde
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=lingao
# Processing Record 17 of Set 5 | lingao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=vardo
# Processing Record 18 of Set 5 | vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=arrecife
# Processing Record 19 of Set 5 | arrecife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=itarema
# Processing Record 20 of Set 5 | itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=amderma
# Processing Record 21 of Set 5 | amderma
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=san+quintin
# Processing Record 22 of Set 5 | san quintin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=rio+grande
# Processing Record 23 of Set 5 | rio grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=igrim
# Processing Record 24 of Set 5 | igrim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=randfontein
# Processing Record 25 of Set 5 | randfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=sibut
# Processing Record 26 of Set 5 | sibut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=senneterre
# Processing Record 27 of Set 5 | senneterre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=olafsvik
# Processing Record 28 of Set 5 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=great+yarmouth
# Processing Record 29 of Set 5 | great yarmouth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=reno
# Processing Record 30 of Set 5 | reno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=faanui
# Processing Record 31 of Set 5 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=ixtapa
# Processing Record 32 of Set 5 | ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=barawe
# Processing Record 33 of Set 5 | barawe
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=qaqortoq
# Processing Record 34 of Set 5 | qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=telemaco+borba
# Processing Record 35 of Set 5 | telemaco borba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=fort-shevchenko
# Processing Record 36 of Set 5 | fort-shevchenko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=rivne
# Processing Record 37 of Set 5 | rivne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kiama
# Processing Record 38 of Set 5 | kiama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=mitu
# Processing Record 39 of Set 5 | mitu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=ginda
# Processing Record 40 of Set 5 | ginda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=barcelos
# Processing Record 41 of Set 5 | barcelos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=palabuhanratu
# Processing Record 42 of Set 5 | palabuhanratu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=nome
# Processing Record 43 of Set 5 | nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=valparaiso
# Processing Record 44 of Set 5 | valparaiso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=karatau
# Processing Record 45 of Set 5 | karatau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=mrirt
# Processing Record 46 of Set 5 | mrirt
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=inongo
# Processing Record 47 of Set 5 | inongo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=auki
# Processing Record 48 of Set 5 | auki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=zaraza
# Processing Record 49 of Set 5 | zaraza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=portland
# Processing Record 50 of Set 5 | portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=talnakh
# Processing Record 1 of Set 6 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=alyangula
# Processing Record 2 of Set 6 | alyangula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=korla
# Processing Record 3 of Set 6 | korla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=karratha
# Processing Record 4 of Set 6 | karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=samalaeulu
# Processing Record 5 of Set 6 | samalaeulu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=coquimbo
# Processing Record 6 of Set 6 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=aquiraz
# Processing Record 7 of Set 6 | aquiraz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=bulnes
# Processing Record 8 of Set 6 | bulnes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=tsihombe
# Processing Record 9 of Set 6 | tsihombe
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=zhengjiatun
# Processing Record 10 of Set 6 | zhengjiatun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=provideniya
# Processing Record 11 of Set 6 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=svetlogorsk
# Processing Record 12 of Set 6 | svetlogorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=katsuura
# Processing Record 13 of Set 6 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=morlaix
# Processing Record 14 of Set 6 | morlaix
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=leningradskiy
# Processing Record 15 of Set 6 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kununurra
# Processing Record 16 of Set 6 | kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=manching
# Processing Record 17 of Set 6 | manching
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=galich
# Processing Record 18 of Set 6 | galich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=malakal
# Processing Record 19 of Set 6 | malakal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kuloy
# Processing Record 20 of Set 6 | kuloy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=hokitika
# Processing Record 21 of Set 6 | hokitika
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=buraydah
# Processing Record 22 of Set 6 | buraydah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=yulara
# Processing Record 23 of Set 6 | yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=saint-philippe
# Processing Record 24 of Set 6 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=grand+centre
# Processing Record 25 of Set 6 | grand centre
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=korem
# Processing Record 26 of Set 6 | korem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=norman+wells
# Processing Record 27 of Set 6 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=saskylakh
# Processing Record 28 of Set 6 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=tutoia
# Processing Record 29 of Set 6 | tutoia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=vanavara
# Processing Record 30 of Set 6 | vanavara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=attawapiskat
# Processing Record 31 of Set 6 | attawapiskat
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=culebra
# Processing Record 32 of Set 6 | culebra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=carnarvon
# Processing Record 33 of Set 6 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=goulburn
# Processing Record 34 of Set 6 | goulburn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=wyndham
# Processing Record 35 of Set 6 | wyndham
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=aparecida+do+taboado
# Processing Record 36 of Set 6 | aparecida do taboado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=nemuro
# Processing Record 37 of Set 6 | nemuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=viedma
# Processing Record 38 of Set 6 | viedma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=zyryanka
# Processing Record 39 of Set 6 | zyryanka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=hakvik
# Processing Record 40 of Set 6 | hakvik
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=santa+isabel
# Processing Record 41 of Set 6 | santa isabel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=saleaula
# Processing Record 42 of Set 6 | saleaula
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=walvis+bay
# Processing Record 43 of Set 6 | walvis bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=batemans+bay
# Processing Record 44 of Set 6 | batemans bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=lolua
# Processing Record 45 of Set 6 | lolua
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=shubarkuduk
# Processing Record 46 of Set 6 | shubarkuduk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=tateyama
# Processing Record 47 of Set 6 | tateyama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=vadamadurai
# Processing Record 48 of Set 6 | vadamadurai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=noumea
# Processing Record 49 of Set 6 | noumea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=san+rafael
# Processing Record 50 of Set 6 | san rafael
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=amarwara
# Processing Record 1 of Set 7 | amarwara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=dubti
# Processing Record 2 of Set 7 | dubti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kulhudhuffushi
# Processing Record 3 of Set 7 | kulhudhuffushi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=mankovo-kalitvenskoye
# Processing Record 4 of Set 7 | mankovo-kalitvenskoye
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=rungata
# Processing Record 5 of Set 7 | rungata
# City not found. Skipping...
# ...
# Processing Record 10 of Set 14 | oreanda
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=manaquiri
# Processing Record 11 of Set 14 | manaquiri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=gabu
# Processing Record 12 of Set 14 | gabu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=belyy+yar
# Processing Record 13 of Set 14 | belyy yar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=rantepao
# Processing Record 14 of Set 14 | rantepao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=fort+smith
# Processing Record 15 of Set 14 | fort smith
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=pestovo
# Processing Record 16 of Set 14 | pestovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=toktogul
# Processing Record 17 of Set 14 | toktogul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=mitchell
# Processing Record 18 of Set 14 | mitchell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=malanje
# Processing Record 19 of Set 14 | malanje
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=bekhtery
# Processing Record 20 of Set 14 | bekhtery
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kodinsk
# Processing Record 21 of Set 14 | kodinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=khorixas
# Processing Record 22 of Set 14 | khorixas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=dicabisagan
# Processing Record 23 of Set 14 | dicabisagan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=gombe
# Processing Record 24 of Set 14 | gombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=yaan
# Processing Record 25 of Set 14 | yaan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=southbridge
# Processing Record 26 of Set 14 | southbridge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=mitsamiouli
# Processing Record 27 of Set 14 | mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kieta
# Processing Record 28 of Set 14 | kieta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=mehamn
# Processing Record 29 of Set 14 | mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=heihe
# Processing Record 30 of Set 14 | heihe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=ishigaki
# Processing Record 31 of Set 14 | ishigaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=krasnyy+oktyabr
# Processing Record 32 of Set 14 | krasnyy oktyabr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=quelimane
# Processing Record 33 of Set 14 | quelimane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=toropets
# Processing Record 34 of Set 14 | toropets
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=mezen
# Processing Record 35 of Set 14 | mezen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=satitoa
# Processing Record 36 of Set 14 | satitoa
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=sao+felix+do+xingu
# Processing Record 37 of Set 14 | sao felix do xingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=jijiga
# Processing Record 38 of Set 14 | jijiga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=koumac
# Processing Record 39 of Set 14 | koumac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=san+cristobal
# Processing Record 40 of Set 14 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=oshkosh
# Processing Record 41 of Set 14 | oshkosh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=saint-pierre
# Processing Record 42 of Set 14 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=namatanai
# Processing Record 43 of Set 14 | namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=tuzha
# Processing Record 44 of Set 14 | tuzha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kupang
# Processing Record 45 of Set 14 | kupang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=praia+da+vitoria
# Processing Record 46 of Set 14 | praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=zhanaozen
# Processing Record 47 of Set 14 | zhanaozen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=nizhneyansk
# Processing Record 48 of Set 14 | nizhneyansk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kiruna
# Processing Record 49 of Set 14 | kiruna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=trutnov
# Processing Record 50 of Set 14 | trutnov
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=sur
# Processing Record 1 of Set 15 | sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=alekseyevsk
# Processing Record 2 of Set 15 | alekseyevsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=notre-dame-du-lac
# Processing Record 3 of Set 15 | notre-dame-du-lac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=miramar
# Processing Record 4 of Set 15 | miramar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=taltal
# Processing Record 5 of Set 15 | taltal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=mayo
# Processing Record 6 of Set 15 | mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=dawei
# Processing Record 7 of Set 15 | dawei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=ust-kamchatsk
# Processing Record 8 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=lahij
# Processing Record 9 of Set 15 | lahij
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=akdepe
# Processing Record 10 of Set 15 | akdepe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=lhuntshi
# Processing Record 11 of Set 15 | lhuntshi
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=yankton
# Processing Record 12 of Set 15 | yankton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=grand+gaube
# Processing Record 13 of Set 15 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=port+hedland
# Processing Record 14 of Set 15 | port hedland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=zunyi
# Processing Record 15 of Set 15 | zunyi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=san-pedro
# Processing Record 16 of Set 15 | san-pedro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=eydhafushi
# Processing Record 17 of Set 15 | eydhafushi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=bonfim
# Processing Record 18 of Set 15 | bonfim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=shchelyayur
# Processing Record 19 of Set 15 | shchelyayur
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=lewiston
# Processing Record 20 of Set 15 | lewiston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=merrill
# Processing Record 21 of Set 15 | merrill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=jalu
# Processing Record 22 of Set 15 | jalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=maragogi
# Processing Record 23 of Set 15 | maragogi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=popova
# Processing Record 24 of Set 15 | popova
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=gejiu
# Processing Record 25 of Set 15 | gejiu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=lamar
# Processing Record 26 of Set 15 | lamar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=yanchukan
# Processing Record 27 of Set 15 | yanchukan
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=pestretsy
# Processing Record 28 of Set 15 | pestretsy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=edmundston
# Processing Record 29 of Set 15 | edmundston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=thaba-tseka
# Processing Record 30 of Set 15 | thaba-tseka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kuche
# Processing Record 31 of Set 15 | kuche
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=egvekinot
# Processing Record 32 of Set 15 | egvekinot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=susuman
# Processing Record 33 of Set 15 | susuman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=megion
# Processing Record 34 of Set 15 | megion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=santa+marta
# Processing Record 35 of Set 15 | santa marta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=racine
# Processing Record 36 of Set 15 | racine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=nizhnyaya+tavda
# Processing Record 37 of Set 15 | nizhnyaya tavda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=changqing
# Processing Record 38 of Set 15 | changqing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=loubomo
# Processing Record 39 of Set 15 | loubomo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=newnan
# Processing Record 40 of Set 15 | newnan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=gizo
# Processing Record 41 of Set 15 | gizo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kitakata
# Processing Record 42 of Set 15 | kitakata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=baruun-urt
# Processing Record 43 of Set 15 | baruun-urt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=cap+malheureux
# Processing Record 44 of Set 15 | cap malheureux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=tengzhou
# Processing Record 45 of Set 15 | tengzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=moron
# Processing Record 46 of Set 15 | moron
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=mbekenyera
# Processing Record 47 of Set 15 | mbekenyera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=vikhorevka
# Processing Record 48 of Set 15 | vikhorevka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=kawalu
# Processing Record 49 of Set 15 | kawalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=medianeira
# Processing Record 50 of Set 15 | medianeira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=gornopravdinsk
# Processing Record 1 of Set 16 | gornopravdinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=inuvik
# Processing Record 2 of Set 16 | inuvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=stromness
# Processing Record 3 of Set 16 | stromness
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=almaznyy
# Processing Record 4 of Set 16 | almaznyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=satuk
# Processing Record 5 of Set 16 | satuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=phon
# Processing Record 6 of Set 16 | phon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=amahai
# Processing Record 7 of Set 16 | amahai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=arroio+grande
# Processing Record 8 of Set 16 | arroio grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=mahenge
# Processing Record 9 of Set 16 | mahenge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=aseri
# Processing Record 10 of Set 16 | aseri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a06a4fc51dd66de1e2b3c6c775b03075&q=aripuana
# Processing Record 11 of Set 16 | aripuana
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 690

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Dikson      RU  73.5069   80.5464      6.93        94         100
# 1         Vaini      TO -21.2000 -175.2000     71.76        94          20
# 2  Ponta Do Sol      PT  32.6667  -17.1000     76.71        78          37
# 3    Butaritari      KI   3.0707  172.7902     80.51        78          46
# 4         Nizwa      OM  22.9333   57.5333     80.91        24           3
# 5       Kahului      US  20.8947 -156.4700     70.84        76           1
# 6     Aanekoski      FI  62.6946   25.8180     46.47        93         100
# 7       Rikitea      PF -23.1203 -134.9692     74.07        88         100
# 8  Constitucion      CL -35.3333  -72.4167     61.68        71         100
# 9        Shache      CN  38.4167   77.2406     50.54        28         100
#
#    Wind Speed Current Description
# 0       10.04     overcast clouds
# 1        5.75          few clouds
# 2        7.09    scattered clouds
# 3        9.57          light rain
# 4        7.38           clear sky
# 5        5.75           clear sky
# 6        6.91     overcast clouds
# 7       17.58       moderate rain
# 8        6.89     overcast clouds
# 9        3.67     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
